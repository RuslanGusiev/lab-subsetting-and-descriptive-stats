# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
# City - string, State - string, Temperature - float

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
'''
L.S. Good!
'''

new_temp = temp[temp.State == 'New York']
new_temp
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
new_temp.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
'''
L.S. Good!
'''

temp[temp.Temperature > 15] [['State', 'City']]
# Out:
#          State      City
# 0     New York       NYC
# 3  Connecticut  Hartford
# 5   New Jersey    Treton
# 6   New Jersey    Newark

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15]['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
'''
L.S. Well done!
'''

temp1 = temp[temp.Temperature > 15]
temp2 = temp1[temp1.Temperature < 20]
temp2
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
'''
L.S. Good!
'''

temp_NY = temp[temp.State == 'New York']
print('mean New York: ',temp_NY.mean(), '\nstd New York: ', temp_NY.std())

temp_Con = temp[temp.State == 'Connecticut']
print('mean Connecticut: ',temp_Con.mean(), '\nstd Connecticut: ', temp_Con.std())

temp_NJ = temp[temp.State == 'New Jersey']
print('mean New Jersey: ',temp_NJ.mean(), '\nstd New Jersey: ', temp_NJ.std())
# Out:
# mean New York:  Temperature    10.740741
# dtype: float64
# std New York:  Temperature    8.133404
# dtype: float64
# mean Connecticut:  Temperature    15.833333
# dtype: float64
# std Connecticut:  Temperature    1.964186
# dtype: float64
# mean New Jersey:  Temperature    21.111111
# dtype: float64
# std New Jersey:  Temperature    1.571348
# dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
# Name - string
# Department, Education, Gender, Title - categorial
# Years, Salary - integer

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
import matplotlib
# %matplotlib inline

'''
L.S. Correct!
'''

employee.hist(bins=20)
# Salary hist: We have 2 employee with salary 30, 2 employee - 35, 2 employee - 55, 1 employee - 60 and 2 employee - 70
# Years hist: 1 employee with 1 year experience, 3 emp - 2 years ....
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10ce707b8>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
round(employee.Salary.mean(), 1)
# Out:
# 48.9

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
'''
L.S. Good!
'''

employee[employee.Salary == employee.Salary.min()]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[employee.Title == 'associate'][employee.Salary > 55]
# Out:
# /anaconda3/envs/tensor/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
'''
L.S. Good, however, there's an easier method: groupby. 
'''

emp_Salary = employee[employee.Years == 1]['Salary']
print('1 year:', emp_Salary.mean(), '\n')

emp_Salary2 = employee[employee.Years == 2]['Salary']
print('2 years:', round(emp_Salary2.mean(), 1), '\n')

emp_Salary3 = employee[employee.Years == 3]['Salary']
print('3 years:', emp_Salary3.mean(), '\n')

emp_Salary4 = employee[employee.Years == 4]['Salary']
print('4 years:', emp_Salary4.mean(), '\n')

emp_Salary7 = employee[employee.Years == 7]['Salary']
print('7 years:', emp_Salary7.mean(), '\n')

emp_Salary8 = employee[employee.Years == 8]['Salary']
print('8 years:', emp_Salary8.mean(), '\n')
# Out:
# 1 year: 35.0
#
# 2 years: 38.3
#
# 3 years: 55.0
#
# 4 years: 35.0
#
# 7 years: 60.0
#
# 8 years: 70.0

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
'''
L.S. Good!
'''

emp_Salary_analyst = employee[employee.Title == 'analyst']['Salary']
print('Analyst average salary: ', emp_Salary_analyst.mean(), '\n')

emp_Salary_associate = employee[employee.Title == 'associate']['Salary']
print('Associate average salary: ', round(emp_Salary_associate.mean(), 1), '\n')

emp_Salary_VP = employee[employee.Title == 'VP']['Salary']
print('VP average salary: ', emp_Salary_VP.mean(), '\n')
# Out:
# Analyst average salary:  32.5
#
# Associate average salary:  56.7
#
# VP average salary:  70.0

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.quantile(0.25)
# first part of distribution with 2 years experience and salary = 35
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Third part of distribution with 7 years experience and salary = 60
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
emp_Salary_M = employee[employee.Gender == 'M']['Salary']
print('Male: ', emp_Salary_M.mean())

emp_Salary_F = employee[employee.Gender == 'F']['Salary']
print('Female :', emp_Salary_F.mean())
# Out:
# Male:  50.0
# Female : 47.5

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
'''
L.S. Correct!
'''

emp_Department_Sales = employee[employee.Department == 'Sales']
print('Sales: \n', emp_Department_Sales.describe(), '\n')

emp_Department_HR = employee[employee.Department == 'HR']
print('HR: \n', emp_Department_HR.describe(), '\n')

emp_Department_IT = employee[employee.Department == 'IT']
print('IT: \n', emp_Department_IT.describe(), '\n')
# Out:
# Sales:
#            Years  Salary
# count  2.000000     2.0
# mean   2.500000    55.0
# std    0.707107     0.0
# min    2.000000    55.0
# 25%    2.250000    55.0
# 50%    2.500000    55.0
# 75%    2.750000    55.0
# max    3.000000    55.0
#
# HR:
#            Years     Salary
# count  3.000000   3.000000
# mean   4.666667  45.000000
# std    3.055050  21.794495
# min    2.000000  30.000000
# 25%    3.000000  32.500000
# 50%    4.000000  35.000000
# 75%    6.000000  52.500000
# max    8.000000  70.000000
#
# IT:
#            Years    Salary
# count  4.000000   4.00000
# mean   4.500000  48.75000
# std    3.511885  19.31105
# min    1.000000  30.00000
# 25%    1.750000  33.75000
# 50%    4.500000  47.50000
# 75%    7.250000  62.50000
# max    8.000000  70.00000

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.zip')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# ...

# %%
# your answer here
#Unnamed, invoiceNo, Quantity, UnitPrice,amount_spent - integers
# StockCode, Description, Country striing
# year, month, day, hour, CustomerID categorial

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
round(orders.UnitPrice.mean(), 2)
# Out:
# 3.12

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
# your answer here
orders.UnitPrice.min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
'''
L.S. Well done!
'''

orders_spain = orders[orders.Country == 'Spain']
orders_spain
#spain_CustomerID = orders_spain.groupby(orders_spain['CustomerID'])
#spain_CustomerID.head()
spain_Customer = orders_spain.groupby(orders_spain['CustomerID']).count()
spain_Customer.head()
# Out:
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12354               58         58         58    58     58   58    58
# 12417               23         23         23    23     23   23    23
# 12421               45         45         45    45     45   45    45
# 12442               12         12         12    12     12   12    12
# 12445                4          4          4     4      4    4     4
#
#             Description  Quantity  InvoiceDate  UnitPrice  Country  \
# CustomerID
# 12354                58        58           58         58       58
# 12417                23        23           23         23       23
# 12421                45        45           45         45       45
# 12442                12        12           12         12       12
# 12445                 4         4            4          4        4
#
#             amount_spent
# CustomerID
# 12354                 58
# 12417                 23
# 12421                 45
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
len(spain_Customer)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
'''
L.S. Nice!
'''

rich_customers = orders[orders.Quantity > 50]
rich_customers.groupby(rich_customers.CustomerID).count().head()
# Out:
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12346                1          1          1     1      1    1     1
# 12347                1          1          1     1      1    1     1
# 12348               19         19         19    19     19   19    19
# 12355                2          2          2     2      2    2     2
# 12356                5          5          5     5      5    5     5
#
#             Description  Quantity  InvoiceDate  UnitPrice  Country  \
# CustomerID
# 12346                 1         1            1          1        1
# 12347                 1         1            1          1        1
# 12348                19        19           19         19       19
# 12355                 2         2            2          2        2
# 12356                 5         5            5          5        5
#
#             amount_spent
# CustomerID
# 12346                  1
# 12347                  1
# 12348                 19
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
rich_customers_Spain = orders[(orders.Quantity > 50) & (orders.Country == 'Spain')]
rich_customers_Spain.head()
# Out:
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
# 4253        6424     536944     20725  2010     12    5    12
# 4254        6425     536944     20728  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot        70  2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue       100  2010-12-03 12:20:00       1.45
#
#       CustomerID Country  amount_spent
# 4250       12557   Spain         115.5
# 4251       12557   Spain         145.0
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders = orders[orders.UnitPrice == 0]
free_orders.head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
# 29080       47068     540372     22090  2011      1    4    16
# 29082       47070     540372     22553  2011      1    4    16
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
# 29080       paper bunting retrospot        24  2011-01-06 16:41:00        0.0
# 29082        plasters in tin skulls        24  2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
import re

'''
L.S. Very good!
'''

lunch_lst = ''.join(list(orders["Description"])) 
pattern = '[a-z]*lunch bag[a-z]*' 

new_lst = re.findall(pattern, lunch_lst)
new_lst
# Out:
# ['plateslunch bag',
#  'lunch bag',
#  'notebooklunch bag',
#  'caseslunch bag',
#  'retrospotlunch bag',
#  'lunch bag',
#  'woodlandlunch bag',
#  'caseslunch bag',
#  'lunch bag',
#  'bluelunch bag',
#  'bottlelunch bag',
#  'bluelunch bag',
#  'lunch bag',
#  'designlunch bag',
#  'lunch bag',
#  'lunch bag',
#  'lunch bag',
#  'lunch bag',
#  'lunch bag',
#  'apronlunch bag',
#  'lunch bag',
#  'boxlunch bag',
#  'boxlunch bag',
#  'holderlunch bag',
#  'bowllunch bag',
#  'designlunch bag',
#  'cutlerylunch bag',
#  'lacelunch bag',
#  'polkadotlunch bag',
#  'jacklunch bag',
#  'lunch bag',
#  'baglunch bag',
#  'polkadotlunch bag',
#  'polkadotlunch bag',
#  'lunch bag',
#  'baglunch bag',
#  'racklunch bag',
#  'setlunch bag',
#  'paddedlunch bag',
#  'heartlunch bag',
#  'shopperlunch bag',
#  'bluelunch bag',
#  'eraserslunch bag',
#  'lunch bag',
#  'retrospotlunch bag',
#  'flowerslunch bag',
#  'lunch bag',
#  'lunch bag',
#  'matcheslunch bag',
#  'polkadotlunch bag',
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
new_lst2 = []
for i in range(len(new_lst)):
    if new_lst[i] not in new_lst2:
        new_lst2.append(new_lst[i])
        
len(new_lst2)         # 414
for i in range(len(new_lst)):
    orders[(orders.Description == new_lst[i]) & (orders.year == 2011)]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
'''
L.S. Why no answer? 
'''

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
'''
L.S. Correct!
'''

orders_08 = orders[orders.month == 8]
orders_08.head()
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
#
#                               Description  Quantity          InvoiceDate  \
# 199475       6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476          scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart        24  2011-08-01 09:31:00
# 199478   single heart zinc t-light holder        12  2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder        12  2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders_08['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby(orders.Country)['amount_spent'].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby(orders.year)['amount_spent'].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
